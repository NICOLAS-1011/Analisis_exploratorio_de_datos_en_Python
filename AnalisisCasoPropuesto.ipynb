# %%
import pandas as pd

# %%
df = pd.read_csv('Data_Caso_Propuesto.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Codigo                  463 non-null    int64
#  1   Ciudad                  463 non-null    object
#  2   Departamento            463 non-null    object
#  3   Barrio                  40 non-null     object
#  4   Direccion               463 non-null    object
#  5   Area Terreno            463 non-null    float64
#  6   Area Construida         463 non-null    float64
#  7   Detalle Disponibilidad  463 non-null    object
#  8   Estrato                 463 non-null    object
#  9   Precio                  463 non-null    float64
#  10  Tipo de Inmueble        463 non-null    object
#  11  Datos Adicionales       118 non-null    object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 43.5+ KB

# %%
df.isnull().sum()
# Out:
# Codigo                      0
# Ciudad                      0
# Departamento                0
# Barrio                    423
# Direccion                   0
# Area Terreno                0
# Area Construida             0
# Detalle Disponibilidad      0
# Estrato                     0
# Precio                      0
# Tipo de Inmueble            0
# Datos Adicionales         345
# dtype: int64

# %%
df.describe()
# Out:
#              Codigo  Area Terreno  Area Construida        Precio
# count    463.000000  4.630000e+02       463.000000  4.630000e+02
# mean   18003.151188  1.515204e+04        87.517279  6.672032e+08
# std     1992.191499  1.827101e+05      1137.469077  3.272992e+09
# min     2575.000000  0.000000e+00         0.000000  4.650000e+06
# 25%    18184.500000  0.000000e+00         0.000000  1.230500e+07
# 50%    18332.000000  0.000000e+00         0.000000  1.587000e+07
# 75%    18539.500000  0.000000e+00         0.000000  1.379955e+08
# max    19344.000000  3.217197e+06     22724.000000  4.523379e+10

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df.hist(bins=20,figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'Codigo'}>,
#         <Axes: title={'center': 'Area Terreno'}>],
#        [<Axes: title={'center': 'Area Construida'}>,
#         <Axes: title={'center': 'Precio'}>]], dtype=object)

# %%
correlacion = df.corr()
correlacion
sns.heatmap(correlacion,xticklabels=correlacion.columns,yticklabels=correlacion.columns,annot=True)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_14508\1386409017.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlacion = df.corr()
# <Axes: >

# %%
vae = 11409
df_limp = df[df['Codigo'] != vae]
df = df_limp

# %%
sns.relplot(x='Area Construida', y='Area Terreno', hue='Ciudad', data=df)

# %%
vae = 12112
df_limp = df[df['Codigo'] != vae]
df = df_limp

# %%
sns.relplot(x='Area Construida', y='Area Terreno', hue='Departamento', data=df)

# %%
correlacion = df.corr()
correlacion
sns.heatmap(correlacion,xticklabels=correlacion.columns,yticklabels=correlacion.columns,annot=True)
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_14508\4058782914.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlacion = df.corr()
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df.hist(bins=20,figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'Codigo'}>,
#         <Axes: title={'center': 'Area Terreno'}>],
#        [<Axes: title={'center': 'Area Construida'}>,
#         <Axes: title={'center': 'Precio'}>]], dtype=object)

# %%
df.describe()
# Out:
#              Codigo   Area Terreno  Area Construida        Precio
# count    461.000000     461.000000       461.000000  4.610000e+02
# mean   18030.234273    3493.129718        38.604121  5.667563e+08
# std     1953.297895   28986.841877       427.915159  2.534675e+09
# min     2575.000000       0.000000         0.000000  4.650000e+06
# 25%    18186.000000       0.000000         0.000000  1.230500e+07
# 50%    18333.000000       0.000000         0.000000  1.587000e+07
# 75%    18547.000000       0.000000         0.000000  1.300992e+08
# max    19344.000000  430399.680000      7269.000000  2.958081e+10
